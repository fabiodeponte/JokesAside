# %%
import os
import pandas as pd

folder_path = "only_true_jokes_CSVs/selection/1-6_6-10_together"

# %%
# List to store individual DataFrames
dataframes = []

# Iterate through all CSV files in the folder
for file_name in os.listdir(folder_path):
    file_path = folder_path+"/"+file_name

    # Check if the file is a CSV
    if file_name.endswith(".csv") and os.path.isfile(file_path):
        try:
            # Load the CSV file into a DataFrame
            df = pd.read_csv(file_path)
            
            # Append the DataFrame to the list
            dataframes.append(df)
            print(f"Loaded: {file_name}")

        except Exception as e:
            print(f"Could not load {file_name}: {e}")

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Display the combined DataFrame
print("Combined DataFrame:")
print(combined_df.head())

# Save the combined DataFrame to a new CSV file (optional)
combined_df.to_csv("combined_dataframe.csv", index=False)
# Out:
# Loaded: selected_jokes_45800_45900.csv
# Loaded: selected_jokes_10700_10800.csv
# Loaded: selected_jokes_77200_77300.csv
# Loaded: selected_jokes_66400_66500.csv
# Loaded: selected_jokes_44900_45000.csv
# Loaded: selected_jokes_57700_57800.csv
# Loaded: selected_jokes_6300_6400.csv
# Loaded: selected_jokes_28100_28200.csv
# Loaded: selected_jokes_21400_21500.csv
# Loaded: selected_jokes_95100_95200.csv
# Loaded: selected_jokes_93900_94000.csv
# Loaded: selected_jokes_44200_44300.csv
# Loaded: selected_jokes_20000_20100.csv
# Loaded: selected_jokes_55400_55500.csv
# Loaded: selected_jokes_94500_94600.csv
# Loaded: selected_jokes_69900_70000.csv
# Loaded: selected_jokes_8200_8300.csv
# Loaded: selected_jokes_62300_62400.csv
# Loaded: selected_jokes_23700_23800.csv
# Loaded: selected_jokes_59900_60000.csv
# Loaded: selected_jokes_12400_12500.csv
# Loaded: selected_jokes_30900_31000.csv
# Loaded: selected_jokes_3500_3600.csv
# Loaded: selected_jokes_76600_76700.csv
# ...

# %%
combined_df
# Out:
#                                                sentence      word  \
# 0     The flat earth community has supporters all ar...     globe
# 1     What do you call a mexican without a car... ca...       car
# 2     What do you call a basement full of redditors?...    cellar
# 3     Why did the tennis player get thrown out of hi...    racket
# 4         What do you call a scary horse? a night-mare.      mare
# ...                                                 ...       ...
# 2801  Each joke has been analyzed, and the serious s...       NaN
# 2802  a cow moves in next door to a horse... ...the ...     neigh
# 2803     what do you call a stack of cats. a meowuntian      meow
# 2804  what did the stonemason break up with the fema...   granite
# 2805  This output lists the jokes that fit your crit...       NaN
#
#                                             explanation  \
# 0       A globe is a spherical representation of Earth.
# 1            A car is a motor vehicle with four wheels.
# ...

# %%
clean_df = combined_df.dropna()

# %%
clean_df.to_csv("only_true_jokes_CSVs/selection/clean_jokes.csv", encoding='utf-8', index=False)

# %%
test = pd.read_csv('only_true_jokes_CSVs/selection/clean_jokes.csv')

# %%
test
# Out:
#                                                sentence      word  \
# 0     The flat earth community has supporters all ar...     globe
# 1     What do you call a mexican without a car... ca...       car
# 2     What do you call a basement full of redditors?...    cellar
# 3     Why did the tennis player get thrown out of hi...    racket
# 4         What do you call a scary horse? a night-mare.      mare
# ...                                                 ...       ...
# 1881  How do you mend a jack-o-lantern? with a pumpk...     patch
# 1882         What do elephants use as a tampons? sheep.     sheep
# 1883  a cow moves in next door to a horse... ...the ...     neigh
# 1884     what do you call a stack of cats. a meowuntian      meow
# 1885  what did the stonemason break up with the fema...   granite
#
#                                             explanation  \
# 0       A globe is a spherical representation of Earth.
# 1            A car is a motor vehicle with four wheels.
# ...
